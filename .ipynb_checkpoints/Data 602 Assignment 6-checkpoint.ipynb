# %% [markdown]
# # Datasets
# I have chosen 4 datasets to explore. The following questions/prompts will be executed/answered for each dataset:
#
# Q1. Load your dataset into python using the pandas library and save data into a
# dataframe named dfi (where i is one of your datasets, for a total of 4).
#
# Q2. Preview your data by calling your dataframe’s name. How many columns and rows
# do you see?
#
# Q3. Examine the shape of your data using the .shape command and the data types of
# your columns using .dtypes.
#
# Q4. Use .describe() on your data. What do you notice about your data? What does this
# command return?
#
# Q5. Use the .head() and .tail() command - what does this do?

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Kobe Dataset

# %%
dfi = pd.read_csv("https://raw.githubusercontent.com/data602sps/datasetspractice/main/kobe.csv")

# %%
dfi
# Out:
#       vs  game quarter     time  \
# 0    ORL     1       1     9:47
# 1    ORL     1       1     9:07
# 2    ORL     1       1     8:11
# 3    ORL     1       1     7:41
# 4    ORL     1       1     7:03
# ..   ...   ...     ...      ...
# 128  ORL     3       4     3:33
# 129  ORL     3       4     2:02
# 130  ORL     3       4  00:23.9
# 131  ORL     3       4  00:06.9
# 132  ORL     3       4  00:00.5
#
#                                            description basket
# 0              Kobe Bryant makes 4-foot two point shot      H
# 1                            Kobe Bryant misses jumper      M
# 2                     Kobe Bryant misses 7-foot jumper      M
# 3    Kobe Bryant makes 16-foot jumper (Derek Fisher...      H
# 4                      Kobe Bryant makes driving layup      H
# ..                                                 ...    ...
# 128                        Bryant Layup Shot: Missed        M
# 129                          Bryant 3pt Shot: Missed        M
# ...

# %% [markdown]
# There are 133 rows and 6 columns in this dataset.

# %% [markdown]
# ### .shape

# %%
dfi.shape
# Out:
# (133, 6)

# %% [markdown]
# ### .dtypes

# %%
dfi.dtypes
# Out:
# vs             object
# game            int64
# quarter        object
# time           object
# description    object
# basket         object
# dtype: object

# %% [markdown]
# ### .describe()

# %%
dfi.describe()
# Out:
#              game
# count  133.000000
# mean     2.902256
# std      1.450521
# min      1.000000
# 25%      1.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000

# %% [markdown]
# The .describe() function shows a statistical summary of dataframe columns that are numeric, including the mean, standard deviation, min and max values, and interquartile values. For this dataframe, the game column is the only numeric column in this dataframe.

# %% [markdown]
# ### .head()
# The .head() function shows the first 5 rows of the dataframe:

# %%
dfi.head()
# Out:
#     vs  game quarter  time                                        description  \
# 0  ORL     1       1  9:47            Kobe Bryant makes 4-foot two point shot
# 1  ORL     1       1  9:07                          Kobe Bryant misses jumper
# 2  ORL     1       1  8:11                   Kobe Bryant misses 7-foot jumper
# 3  ORL     1       1  7:41  Kobe Bryant makes 16-foot jumper (Derek Fisher...
# 4  ORL     1       1  7:03                    Kobe Bryant makes driving layup
#
#   basket
# 0      H
# 1      M
# 2      M
# 3      H
# 4      H

# %% [markdown]
# ### .tail()
# The .tail() function shows the last 5 rows of the dataframe:

# %%
dfi.tail()
# Out:
#       vs  game quarter     time                         description basket
# 128  ORL     3       4     3:33         Bryant Layup Shot: Missed        M
# 129  ORL     3       4     2:02           Bryant 3pt Shot: Missed        M
# 130  ORL     3       4  00:23.9           Bryant 3pt Shot: Missed        M
# 131  ORL     3       4  00:06.9           Bryant 3pt Shot: Missed        M
# 132  ORL     3       4  00:00.5  Bryant Layup Shot: Made (31 PTS)        H

# %% [markdown]
# ## NBA Dataset

# %%
dfii = pd.read_csv("https://raw.githubusercontent.com/data602sps/datasetspractice/main/nba.csv")

# %%
dfii
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# There are 458 rows and 9 columns in this dataframe.

# %% [markdown]
# ### .shape

# %%
dfii.shape
# Out:
# (458, 9)

# %% [markdown]
# ### .dtypes

# %%
dfii.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %% [markdown]
# ### .describe()

# %%
dfii.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %% [markdown]
# In this dataframe, Number, Age, Weight, and Salary are the only columns that are numeric, and therefore have summary statistics available using .describe().

# %% [markdown]
# ### .head()
# First 5 rows of the dataframe:

# %%
dfii.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# ### .tail()
# Last 5 rows of the dataframe:

# %%
dfii.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %% [markdown]
# ## Music Streams Dataset

# %%
dfiii = pd.read_csv("https://raw.githubusercontent.com/moham6839/Data602_Assignment6/main/Streams.csv")

# %%
dfiii
# Out:
#                  Song                             Artist  Streams (Billions)  \
# 0     Blinding Lights                         The Weeknd               3.449
# 1        Shape of You                         Ed Sheeran               3.398
# 2        Dance Monkey                        Tones And I               2.770
# 3   Someone You Loved                      Lewis Capaldi               2.680
# 4            Rockstar    Post Malone featuring 21 Savage               2.620
# ..                ...                                ...                 ...
# 95            7 Years                       Lukas Graham               1.529
# 96             Yellow                           Coldplay               1.527
# 97              Sugar                           Maroon 5               1.524
# 98          Despacito  Luis Fonsi featuring Daddy Yankee               1.522
# 99  Don't Stop Me Now                              Queen               1.521
#
#    Release Date
# 0     29-Nov-19
# ...

# %% [markdown]
# There are 100 rows and 4 columns in this dataframe.

# %% [markdown]
# ### .shape

# %%
dfiii.shape
# Out:
# (100, 4)

# %% [markdown]
# ### .dtypes

# %%
dfiii.dtypes
# Out:
# Song                   object
# Artist                 object
# Streams (Billions)    float64
# Release Date           object
# dtype: object

# %% [markdown]
# ### .describe()

# %%
dfiii.describe()
# Out:
#        Streams (Billions)
# count          100.000000
# mean             1.896000
# std              0.371272
# min              1.521000
# 25%              1.647000
# 50%              1.770500
# 75%              2.046000
# max              3.449000

# %% [markdown]
# The Streams column is numeric and therefore has a statistical summary.

# %% [markdown]
# ### .head()
# First 5 rows of the dataframe:

# %%
dfiii.head()
# Out:
#                 Song                           Artist  Streams (Billions)  \
# 0    Blinding Lights                       The Weeknd               3.449
# 1       Shape of You                       Ed Sheeran               3.398
# 2       Dance Monkey                      Tones And I               2.770
# 3  Someone You Loved                    Lewis Capaldi               2.680
# 4           Rockstar  Post Malone featuring 21 Savage               2.620
#
#   Release Date
# 0    29-Nov-19
# 1    06-Jan-17
# 2    10-May-19
# 3    08-Nov-18
# 4    15-Sep-17

# %% [markdown]
# ### .tail()
# Last 5 rows of the dataframe:

# %%
dfiii.tail()

# %% [markdown]
# ## Earthquake Dataset

# %%
dfiiii = pd.read_csv("https://raw.githubusercontent.com/moham6839/Data602_Assignment6/main/earthquake_data.csv")

# %%
dfiiii
# Out:
#                                                  title  magnitude  \
# 0         M 7.0 - 18 km SW of Malango, Solomon Islands        7.0
# 1             M 6.9 - 204 km SW of Bengkulu, Indonesia        6.9
# 2                                             M 7.0 -         7.0
# 3                  M 7.3 - 205 km ESE of Neiafu, Tonga        7.3
# 4                                             M 6.6 -         6.6
# ..                                                 ...        ...
# 777  M 7.7 - 28 km SSW of Puerto El Triunfo, El Sal...        7.7
# 778              M 6.9 - 47 km S of Old Harbor, Alaska        6.9
# 779             M 7.1 - 16 km NE of Port-Olry, Vanuatu        7.1
# 780                      M 6.8 - Mindanao, Philippines        6.8
# 781           M 7.5 - 21 km SE of Lukatan, Philippines        7.5
#
#             date_time  cdi  mmi  alert  tsunami  sig net  nst   dmin   gap  \
# 0    22-11-2022 02:03    8    7  green        1  768  us  117  0.509  17.0
# ...

# %% [markdown]
# There are 782 rows and 19 columns.

# %% [markdown]
# ### .shape

# %%
dfiiii.shape
# Out:
# (782, 19)

# %% [markdown]
# ### .dtypes

# %%
dfiiii.dtypes
# Out:
# title         object
# magnitude    float64
# date_time     object
# cdi            int64
# mmi            int64
# alert         object
# tsunami        int64
# sig            int64
# net           object
# nst            int64
# dmin         float64
# gap          float64
# magType       object
# depth        float64
# latitude     float64
# longitude    float64
# location      object
# continent     object
# country       object
# dtype: object

# %% [markdown]
# ### .describe()

# %%
dfiiii.describe()
# Out:
#         magnitude         cdi         mmi     tsunami          sig  \
# count  782.000000  782.000000  782.000000  782.000000   782.000000
# mean     6.941125    4.333760    5.964194    0.388747   870.108696
# std      0.445514    3.169939    1.462724    0.487778   322.465367
# min      6.500000    0.000000    1.000000    0.000000   650.000000
# 25%      6.600000    0.000000    5.000000    0.000000   691.000000
# 50%      6.800000    5.000000    6.000000    0.000000   754.000000
# 75%      7.100000    7.000000    7.000000    1.000000   909.750000
# max      9.100000    9.000000    9.000000    1.000000  2910.000000
#
#               nst        dmin         gap       depth    latitude   longitude
# count  782.000000  782.000000  782.000000  782.000000  782.000000  782.000000
# mean   230.250639    1.325757   25.038990   75.883199    3.538100   52.609199
# std    250.188177    2.218805   24.225067  137.277078   27.303429  117.898886
# ...

# %% [markdown]
# The columns of this dataframe shown above are numeric columns and displays statistical summaries for each column respectively.

# %% [markdown]
# ### .head()
# First 5 rows of the dataframe:

# %%
dfiiii.head()
# Out:
#                                           title  magnitude         date_time  \
# 0  M 7.0 - 18 km SW of Malango, Solomon Islands        7.0  22-11-2022 02:03
# 1      M 6.9 - 204 km SW of Bengkulu, Indonesia        6.9  18-11-2022 13:37
# 2                                      M 7.0 -         7.0  12-11-2022 07:09
# 3           M 7.3 - 205 km ESE of Neiafu, Tonga        7.3  11-11-2022 10:48
# 4                                      M 6.6 -         6.6  09-11-2022 10:14
#
#    cdi  mmi  alert  tsunami  sig net  nst   dmin   gap magType    depth  \
# 0    8    7  green        1  768  us  117  0.509  17.0     mww   14.000
# 1    4    4  green        0  735  us   99  2.229  34.0     mww   25.000
# 2    3    3  green        1  755  us  147  3.125  18.0     mww  579.000
# 3    5    5  green        1  833  us  149  1.865  21.0     mww   37.000
# 4    0    2  green        1  670  us  131  4.998  27.0     mww  624.464
#
# ...

# %% [markdown]
# ### .tail()
# Last 5 rows of the dataframe:

# %%
dfiiii.tail()
# Out:
#                                                  title  magnitude  \
# 777  M 7.7 - 28 km SSW of Puerto El Triunfo, El Sal...        7.7
# 778              M 6.9 - 47 km S of Old Harbor, Alaska        6.9
# 779             M 7.1 - 16 km NE of Port-Olry, Vanuatu        7.1
# 780                      M 6.8 - Mindanao, Philippines        6.8
# 781           M 7.5 - 21 km SE of Lukatan, Philippines        7.5
#
#             date_time  cdi  mmi alert  tsunami  sig net  nst  dmin  gap  \
# 777  13-01-2001 17:33    0    8   NaN        0  912  us  427   0.0  0.0
# 778  10-01-2001 16:02    5    7   NaN        0  745  ak    0   0.0  0.0
# 779  09-01-2001 16:49    0    7   NaN        0  776  us  372   0.0  0.0
# 780  01-01-2001 08:54    0    5   NaN        0  711  us   64   0.0  0.0
# 781  01-01-2001 06:57    0    7   NaN        0  865  us  324   0.0  0.0
#
#     magType  depth  latitude  longitude                        location  \
# ...
